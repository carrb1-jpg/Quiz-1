# %% [markdown]
# # Comprehensive k-Nearest Neighbors Assignment
# **Student:** Bryan Carrillos
# **Course:** AIM – Machine Learning II

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing

# Load
cal = fetch_california_housing(as_frame=True)
df = cal.frame.copy()
df = df.rename(columns={"MedHouseVal": "Target_MedHouseVal"})  # make target explicit

target_col = "Target_MedHouseVal"
feature_cols = [c for c in df.columns if c != target_col]

print("Shape:", df.shape)
display(df.head())
print("\nInfo:")
print(df.info())
print("\nDescribe:")
display(df.describe(include="all"))
print("\nTarget:", target_col)
print("Features:", feature_cols)
# Out:
# Shape: (20640, 9)
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Target_MedHouseVal
# 0    -122.23               4.526
# 1    -122.22               3.585
# 2    -122.24               3.521
# 3    -122.25               3.413
# 4    -122.25               3.422
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MedInc              20640 non-null  float64
# ...

# %%
plt.figure(figsize=(8,4))
df[target_col].hist(bins=40)
plt.title("Distribution of Median House Values")
plt.xlabel("Median House Value ($100,000s)")
plt.ylabel("Count")
plt.show()

plt.figure(figsize=(6,4))
plt.boxplot(df[target_col])
plt.title("Target Boxplot (Outliers Check)")
plt.ylabel("Median House Value")
plt.show()

# %%
df[feature_cols].hist(bins=40, figsize=(12,8))
plt.suptitle("Feature Distributions", y=1.02)
plt.tight_layout()
plt.show()

# Correlation matrix & heatmap
corr = df.corr(numeric_only=True)
plt.figure(figsize=(8,6))
plt.imshow(corr, interpolation="nearest")
plt.title("Correlation Heatmap")
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns, rotation=90)
plt.yticks(range(len(corr)), corr.columns)
plt.tight_layout()
plt.show()

# Scatter vs target
for col in feature_cols:
    plt.figure(figsize=(6,4))
    plt.scatter(df[col], df[target_col], s=10, alpha=0.3)
    plt.xlabel(col)
    plt.ylabel(target_col)
    plt.title(f"{col} vs {target_col}")
    plt.tight_layout()
    plt.show()

# === Part 1.2C: Geographic analysis ===
sc = plt.scatter(df["Longitude"], df["Latitude"], c=df[target_col], s=10, alpha=0.5)
plt.colorbar(sc, label="Median House Value")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("California Prices by Geography")
plt.show()

# === Part 1.2D: Top-3 correlations + trend lines ===
corr_with_target = corr[target_col].drop(target_col).abs().sort_values(ascending=False)
top3 = list(corr_with_target.head(3).index)
print("Top-3 features correlated with target:", top3)

for col in top3:
    x = df[col].values
    y = df[target_col].values
    plt.figure(figsize=(6,4))
    plt.scatter(x, y, s=10, alpha=0.3, label="data")
    coef = np.polyfit(x, y, 1)           # linear trend line
    xs = np.linspace(x.min(), x.max(), 200)
    ys = np.polyval(coef, xs)
    plt.plot(xs, ys, label=f"fit: y={coef[0]:.3f}x+{coef[1]:.3f}")
    plt.xlabel(col)
    plt.ylabel(target_col)
    plt.title(f"{col} vs {target_col} (with trend)")
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# Top-3 features correlated with target: ['MedInc', 'AveRooms', 'Latitude']

# %%
sc = plt.scatter(df["Longitude"], df["Latitude"],
                 c=df[target_col], cmap="viridis", s=10, alpha=0.5)
plt.colorbar(sc, label="Median House Value ($100,000s)")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("California Housing Prices by Geography")
plt.show()

# %% [markdown]
# The target variable represents median house value and it displays a right-skewed distribution. Most homes sell for less than $300,000, but there are a lot of outliers on the higher end, reflective of the high-priced coastal markets of California. These high-value outliers are confirmed in the boxplot. This skew indicates that applying some kind of transformation and scaling (e.g., log-scaling) will help with variance reduction and modeling at a later stage. Based on feature analysis, median income was the most notable predictor of housing price, then latitude and the average number of rooms. Scatter plots reveal a distinct positive relationship between income and price, such that an area with a higher median income tends to have more expensive homes. On the other side, average rooms, average bedrooms, and occupancy all become correlated, which can cause multicollinearity issues if not handled properly. These insights are supported by the geographic analysis. Houses built on coastlines, particularly around San Francisco and Los Angeles, are much more expensive than those built inland and in rural areas. Location is also important in predicting house prices. Thus, the EDA can tell us that income and location are some of the most powerful predictors but that the k-NN model will ultimately need to solve issues such as skewed distributions and multicollinearity in the model.

# %%
print("Missing values per column:")
print(df.isnull().sum())

# Quick check if any column has missing values
if df.isnull().sum().any():
    print("There are missing values. Further handling required.")
else:
    print("No missing values detected.")
# Out:
# Missing values per column:
# MedInc                0
# HouseAge              0
# AveRooms              0
# AveBedrms             0
# Population            0
# AveOccup              0
# Latitude              0
# Longitude             0
# Target_MedHouseVal    0
# dtype: int64
# No missing values detected.

# %% [markdown]
# No missing values were found in the dataset. Therefore, no imputation or special handling was required for this step.

# %%
import numpy as np
import pandas as pd

# Method 1: IQR Outlier Detection
def detect_outliers_iqr(data, column, factor=1.5):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - factor * IQR
    upper = Q3 + factor * IQR
    return (data[column] < lower) | (data[column] > upper)

# Method 2: Z-Score Outlier Detection
def detect_outliers_zscore(data, column, threshold=3):
    mean = data[column].mean()
    std = data[column].std()
    z_scores = (data[column] - mean) / std
    return np.abs(z_scores) > threshold

# Apply both methods to all features + target
outlier_summary = {}
for col in feature_cols + [target_col]:
    iqr_outliers = detect_outliers_iqr(df, col).sum()
    z_outliers = detect_outliers_zscore(df, col).sum()
    outlier_summary[col] = {"IQR": iqr_outliers, "Z-score": z_outliers}

outlier_df = pd.DataFrame(outlier_summary).T
print("Outlier counts per feature:")
display(outlier_df)
# Out:
# Outlier counts per feature:
#                      IQR  Z-score
# MedInc               681      345
# HouseAge               0        0
# AveRooms             511      133
# AveBedrms           1424      145
# Population          1196      342
# AveOccup             711        8
# Latitude               0        0
# Longitude              0        0
# Target_MedHouseVal  1071        0

# %%
plt.figure(figsize=(12,8))
df[feature_cols + [target_col]].boxplot()
plt.title("Boxplots Before Outlier Removal")
plt.xticks(rotation=45)
plt.show()

# Remove outliers using IQR (example choice)
clean_df = df.copy()
for col in feature_cols + [target_col]:
    mask = detect_outliers_iqr(clean_df, col)
    clean_df = clean_df[~mask]

print("Original shape:", df.shape)
print("After removing outliers (IQR):", clean_df.shape)

# Boxplots after outlier removal
plt.figure(figsize=(12,8))
clean_df[feature_cols + [target_col]].boxplot()
plt.title("Boxplots After Outlier Removal (IQR)")
plt.xticks(rotation=45)
plt.show()
# Out:
# Original shape: (20640, 9)
# After removing outliers (IQR): (16232, 9)

# %% [markdown]
# The IQR method detected many more outliers compared to the Z-score method, which makes sense because several features are skewed.
# Boxplots before removal showed extreme values in features such as average rooms, population, and target house value.
# After applying the IQR method, these extremes were reduced, and the dataset size dropped from 20,640 to about 16,322 rows.
# I chose the IQR method because it is more robust to skewed data, which is common in housing datasets.

# %%
import numpy as np
import pandas as pd

# Method 1: IQR Outlier Detection
def detect_outliers_iqr(data, column, factor=1.5):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - factor * IQR
    upper = Q3 + factor * IQR
    return (data[column] < lower) | (data[column] > upper)

# Method 2: Z-Score Outlier Detection
def detect_outliers_zscore(data, column, threshold=3):
    mean = data[column].mean()
    std = data[column].std()
    z_scores = (data[column] - mean) / std
    return np.abs(z_scores) > threshold

# Apply both methods to all features + target
outlier_summary = {}
for col in feature_cols + [target_col]:
    iqr_outliers = detect_outliers_iqr(df, col).sum()
    z_outliers = detect_outliers_zscore(df, col).sum()
    outlier_summary[col] = {"IQR": iqr_outliers, "Z-score": z_outliers}

outlier_df = pd.DataFrame(outlier_summary).T
print("Outlier counts per feature:")
display(outlier_df)
# Out:
# Outlier counts per feature:
#                      IQR  Z-score
# MedInc               681      345
# HouseAge               0        0
# AveRooms             511      133
# AveBedrms           1424      145
# Population          1196      342
# AveOccup             711        8
# Latitude               0        0
# Longitude              0        0
# Target_MedHouseVal  1071        0

# %%
plt.figure(figsize=(12,8))
df[feature_cols + [target_col]].boxplot()
plt.title("Boxplots Before Outlier Removal")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12,8))
clean_df[feature_cols + [target_col]].boxplot()
plt.title("Boxplots After Outlier Removal (IQR)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# I developed some new features to boost the predictive power of the dataset. Ratio Features: Rooms per household, bedrooms per room, population per household: give us richer density and housing qualities than raw counts. Household-level insights that could impact housing prices are captured by these ratios. Geographic Features: The distance from Los Angeles and San Francisco was also included as proximity to major economic centers, which often means homes near the cities have higher cost properties. A coastal proximity variable was also added to account for being closer to the California coast, where housing demand is typically higher. Categorical Features: Median income divided into categories (Low, Medium, High, Very High) to simplify income implications of the effects on house value. And house age was also divided into New, Medium and Old in order to capture generational variation in housing. This allows our k-NN model to capture location and household structure and economic consequences over time for housing.

# %%
import numpy as np

def euclidean_distance(point1, point2):
    """
    Calculate Euclidean distance between two points
    """
    return np.sqrt(np.sum((point1 - point2) ** 2))

def manhattan_distance(point1, point2):
    """
    Calculate Manhattan distance between two points
    """
    return np.sum(np.abs(point1 - point2))

def minkowski_distance(point1, point2, p=2):
    """
    Calculate Minkowski distance between two points
    (p=1 => Manhattan, p=2 => Euclidean)
    """
    return np.sum(np.abs(point1 - point2) ** p) ** (1/p)

# Quick test
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

print("Euclidean:", euclidean_distance(a, b))
print("Manhattan:", manhattan_distance(a, b))
print("Minkowski (p=3):", minkowski_distance(a, b, p=3))
# Out:
# Euclidean: 5.196152422706632
# Manhattan: 9
# Minkowski (p=3): 4.3267487109222245

# %%
import numpy as np

class CustomKNN:
    def __init__(self, k=5, distance_metric='euclidean', weights='uniform'):
        """
        Custom implementation of k-NN
        k: number of neighbors (int)
        distance_metric: 'euclidean', 'manhattan', 'minkowski'
        weights: 'uniform' or 'distance'
        """
        self.k = int(k)
        self.distance_metric = distance_metric
        self.weights = weights
        self.X_train = None
        self.y_train = None

    def fit(self, X, y):
        """Store training data"""
        self.X_train = np.asarray(X, dtype=float)
        self.y_train = np.asarray(y, dtype=float)
        if self.X_train.ndim != 2:
            raise ValueError("X must be 2D array.")
        if self.y_train.ndim != 1:
            raise ValueError("y must be 1D array.")
        if len(self.X_train) != len(self.y_train):
            raise ValueError("X and y must have same length.")

    def _calculate_distance(self, p1, p2):
        """Calculate distance using the selected metric"""
        if self.distance_metric == 'euclidean':
            return np.sqrt(np.sum((p1 - p2) ** 2))
        elif self.distance_metric == 'manhattan':
            return np.sum(np.abs(p1 - p2))
        elif self.distance_metric == 'minkowski':
            return np.sum(np.abs(p1 - p2) ** 3) ** (1/3)  # p=3
        else:
            raise ValueError("Unsupported distance metric.")

    def _get_neighbors(self, x):
        """Return a list of (index, distance) for the k nearest neighbors"""
        dists = [(i, self._calculate_distance(x, xi)) for i, xi in enumerate(self.X_train)]
        dists.sort(key=lambda t: t[1])
        return dists[:self.k]

    def predict_single(self, x):
        """Predict target for a single sample (uniform or distance weights)"""
        neighbors = self._get_neighbors(np.asarray(x, dtype=float))
        idxs = [i for i, _ in neighbors]
        dvals = np.array([d for _, d in neighbors], dtype=float)
        yvals = self.y_train[idxs]

        if self.weights == 'uniform':
            return float(np.mean(yvals))
        elif self.weights == 'distance':
            w = 1.0 / (dvals + 1e-5)  # avoid div-by-zero
            return float(np.average(yvals, weights=w))
        else:
            raise ValueError("weights must be 'uniform' or 'distance'.")

    def predict(self, X):
        """Predict targets for multiple samples"""
        X = np.asarray(X, dtype=float)
        return np.array([self.predict_single(row) for row in X])

    def score(self, X, y):
        """R^2 score on given test data"""
        y = np.asarray(y, dtype=float)
        y_pred = self.predict(X)
        ss_res = np.sum((y - y_pred) ** 2)
        ss_tot = np.sum((y - np.mean(y)) ** 2)
        return 1 - ss_res / ss_tot
